# %%
# login Authentication using conditional Statement
# both userman and passward is correct
# userman is correct but passward is incorrecte
# userman is incorrect
# write a program that propmt the user to enter a username nad passward



predifiened_userman = input("enter your userman: ")
predifiened_passward = input("enter your passward:")

Username1 = input("enter your userman: ")
Passward1 = input("enter your passward:")

if Username1 == predifiened_userman:
    if Passward1 == predifiened_passward:
        print("you are logged in")
    else:
        print("invalid passward")
else:
    print("invalid userman")
# Out:
# enter your userman: Raju
# enter your passward:Yu8999
# enter your userman: raji
# enter your passward:Yu8999
# invalid userman

# %%
#
predefined_username = input("Set username: ")
predefined_password = input("Set password: ")

#
username = input("Enter username: ")
password = input("Enter password: ")

#
if username == predefined_username and password == predefined_password:
    print("You are logged in")
elif username != predefined_username:
    print("Invalid username")
else:
    print("Invalid password")
# Out:
# Set username: Rahul
# Set password: 8999
# Enter username: Rahul
# Enter password: 8999
# You are logged in

# %%
username = "Rahul900"
passward = "Rahul@7887"

#

username1 = input("Enter username:")
passward1 = input("Enter passward:")

#

if username1 == username:
  if passward1 == passward:
    print("you are logged in")
  else:
    print("invalid passward")
else:
  print("invalid passward")
# Out:
# Enter username:Rahul900
# Enter passward:Rahul@788
# invalid passward

# %%
username = input("Enter a username:")
passward = input("Enter a passward:")

#

username1 = input("Enter username:")
passward1 = input("Enter passward:")

#

if username1 == username:
  if passward1 == passward:
    print("you are logged in")
  else:
    print("invalid passward")
else:
  print("invalid passward")
# Out:
# Enter a username:Rahul
# Enter a passward:9000
# Enter username:Rahul
# Enter passward:9000
# you are logged in

# %%
username = input("Enter a username: ")
password = input("Enter a password: ")

print("\n--- Login ---")

username1 = input("Enter username: ")
password1 = input("Enter password: ")

if username1 == username and password1 == password:
    print("You are logged in")
elif username1 != username:
    print("Invalid username")
else:
    print("Invalid password")
# Out:
# Enter a username: Rahul
# Enter a password: 8999
#
# --- Login ---
# Enter username: Rahul
# Enter password: 8999
# You are logged in

# %%
# Registration
username = input("Enter a username: ")
password = input("Enter a password: ")

print("\n--- Login ---")

# Login
username1 = input("Enter username: ")
password1 = input("Enter password: ")

if username1 == username and password1 == password:
    student_name = input("Enter student name: ")
    print(f"Welcome {student_name}, you are logged in successfully ✅")

elif username1 != username:
    print("Invalid username ❌")

else:
    print("Invalid password ❌")
# Out:
# Enter a username: Rahul
# Enter a password: 8999
#
# --- Login ---
# Enter username: Rahul
# Enter password: 8999
# Enter student name: Rahul
# Welcome Rahul, you are logged in successfully ✅

# %%
# Registration
username = input("Enter a username: ")
password = input("Enter a password: ")

print("\n--- Login ---")

# Login
username1 = input("Enter username: ")
password1 = input("Enter password: ")

if username1 == username and password1 == password:
    student_name = input("Enter student name: ")
    print(f"Welcome {student_name}, you are logged in successfully ✅")

elif username1 == username and password1 != password:
    print("Invalid username ❌")

else:
    print("Invalid password ❌")
# Out:
# Enter a username: Rahul
# Enter a password: 9000
#
# --- Login ---
# Enter username: Rahul
# Enter password: 8999
# Invalid username ❌

# %%
# Registration

UserName = input("Enter a username: ")
PassWard = input("Enter a passward: ")

print("------------")

# login

Username = input("Enter username: ")
Passward = input("Enter passward: ")

if Username == UserName:
  if Passward == PassWard:
    print("Welcome to Login System")
  else:
    print("Invalid passward")
else:
  print("Invalid username")
# Out:
# Enter a username: Rahul
# Enter a passward: 7888
# ------------
# Enter username: Rahul
# Enter passward: 7888
# Welcome to Login System

# %%
# Registration

UserName = input("Enter a username: ")
PassWard = input("Enter a passward: ")

print("------------")

# login

Username = input("Enter username: ")
Passward = input("Enter passward: ")

if Username == UserName:
  if Passward == PassWard:
    print("Welcome to Login System")
  else:
    print("Invalid passward")
else:
  print("Invalid username")
# Out:
# Enter a username: Rahul
# Enter a passward: 7888
# ------------
# Enter username: Rahul
# Enter passward: 8999
# Invalid passward

# %%
# Registration

UserName = input("Enter a username: ")
PassWard = input("Enter a passward: ")

print("------------")

# login

Username = input("Enter username: ")
Passward = input("Enter passward: ")

if Username == UserName:
  if Passward == PassWard:
    print("Welcome to Login System")
  else:
    print("Invalid passward")
else:
  print("Invalid username")
# Out:
# Enter a username: Raju90
# Enter a passward: 6777
# ------------
# Enter username: rajui
# Enter passward: 6777
# Invalid username

# %%
# Registration

UserName = input("Enter a username: ")
PassWard = input("Enter a passward: ")

print("------------")

# login

Username = input("Enter username: ")
Passward = input("Enter passward: ")

if Username == UserName:
  if Passward == PassWard:
    print("Welcome to Login System")
  else:
    print("Invalid passward")
elif Username != UserName:
  if Passward != PassWard:
    print("Welcome to Login System error")
  else:
    print("Invalid username")
else:
  print("Invalid username")
# Out:
# Enter a username: Raj
# Enter a passward: 899
# ------------
# Enter username: Rak
# Enter passward: 89
# Welcome to Login System error

# %%
# Registration

UserName = input("Enter a username: ")
PassWard = input("Enter a passward: ")

print("------------")

# login

Username = input("Enter username: ")
Passward = input("Enter passward: ")

if Username == UserName:
  if Passward == PassWard:
    print("Welcome to Login System")
  else:
    print("Invalid passward")
elif Username != UserName:
  if Passward != PassWard:
    print("Welcome to Login System error")
  else:
    print("Invalid username")
else:
  print("Invalid username")
# Out:
# Enter a username: raj
# Enter a passward: 677
# ------------
# Enter username: raj
# Enter passward: 677
# Welcome to Login System

# %%
# Registration

UserName = input("Enter a username: ")
PassWard = input("Enter a passward: ")

print("------------")

# login

Username = input("Enter username: ")
Passward = input("Enter passward: ")

if Username == UserName:
  if Passward == PassWard:
    print("Welcome to Login System")
  else:
    print("Invalid passward")
elif Username != UserName:
  if Passward != PassWard:
    print("Welcome to Login System error")
  else:
    print("Invalid username and Passward")
else:
  print("Invalid username")
# Out:
# Enter a username: Ramu
# Enter a passward: 9000
# ------------
# Enter username: Ramu
# Enter passward: 9008
# Invalid passward

# %%
# Registration

UserName = input("Enter a username: ")
PassWard = input("Enter a passward: ")

print("------------")

# login

Username = input("Enter username: ")
Passward = input("Enter passward: ")

if Username == UserName:
  if Passward == PassWard:
    print("Welcome to Login System")
  else:
    print("Invalid passward")
elif Username != UserName:
  if Passward != PassWard:
    print("Welcome to Login System error")
  else:
    print("Invalid username and passward")
else:
  print("Invalid username")
# Out:
# Enter a username: ram
# Enter a passward: 9000
# ------------
# Enter username: rak
# Enter passward: 9000
# Invalid username and passward

# %%
# Registration

UserName = input("Enter a username: ")
PassWard = input("Enter a passward: ")

print("------------")

# login

Username = input("Enter username: ")
Passward = input("Enter passward: ")

if Username == UserName:
  if Passward == PassWard:
    print("Welcome to Login System")
  else:
    print("Invalid passward")
elif Username != UserName:
  if Passward != PassWard:
    print("Welcome to Login System error")
  else:
    print("Invalid username")
else:
  print("Invalid username")

# %%
# Registration

UserName = input("Enter a username: ")
PassWard = input("Enter a passward: ")

print("------------")

# login

Username = input("Enter username: ")
Passward = input("Enter passward: ")

if Username == UserName:
  if Passward == PassWard:
    name = input(" Enter a name: ")
    print(f"{name},Welcome to Login System")
  else:
    print("Invalid passward")
elif Username != UserName:
  if Passward != PassWard:
    print("Welcome to Login System error")
  else:
    print("Invalid username")
else:
  print("Invalid username")
# Out:
# Enter a username: Raju
# Enter a passward: 8999
# ------------
# Enter username: Raju
# Enter passward: 8999
#  Enter a name: Ram
# Ram,Welcome to Login System

# %%
# Registration for login

UserName = input("Enter a username: ")
PassWard = input("Enter a passward: ")

print("------------")

# login

Username = input("Enter username: ")
Passward = input("Enter passward: ")

if Username == UserName and Passward == PassWard:
  print("Welcome to login system")
else:
  print("Invalid username and passward")
# Out:
# Enter a username: Raju
# Enter a passward: 8999
# ------------
# Enter username: Raju
# Enter passward: 8999
# Welcome to login system

# %%
# Registration for login

UserName = input("Enter a username: ")
PassWard = input("Enter a passward: ")

print("------------")

# login

Username = input("Enter username: ")
Passward = input("Enter passward: ")

if Username == UserName and Passward == PassWard:
  print("Welcome to login system")
else:
  print("Invalid username and passward")
# Out:
# Enter a username: Raj
# Enter a passward: 90
# ------------
# Enter username: raj
# Enter passward: 90
# Invalid username and passward

# %%
# Registration for login

UserName = input("Enter a username: ")
PassWard = input("Enter a passward: ")

print("------------")

# login

Username = input("Enter username: ")
Passward = input("Enter passward: ")

if Username == UserName and Passward == PassWard:
  Student_name = input("Enter student name: ")
  print(f"{Student_name},Welcome to login system")
else:
  print("Invalid username and passward")
# Out:
# Enter a username: Raju
# Enter a passward: 900
# ------------
# Enter username: Raju
# Enter passward: 900
# Enter student name: Raju
# Raju,Welcome to login system

# %%
# check student eligibility nor not

Maths_Marks = int(input("Enter Maths Marks: "))
English_Marks = int(input("Enter English Marks: "))
Science_Marks = int(input("Enter Science Marks: "))

Total_Marks_of_Three_subject = Maths_Marks + English_Marks + Science_Marks
print(f"Total marks of three subject is: {Total_Marks_of_Three_subject}")
total_marks_of_Maths_Marks_English = Maths_Marks + English_Marks
print(f"Total marks of Maths and English is: {total_marks_of_Maths_Marks_English}")
# Out:
# Enter Maths Marks: 78
# Enter English Marks: 89
# Enter Science Marks: 90
# Total marks of three subject is: 257
# Total marks of Maths and English is: 167

# %%
Maths_Marks = int(input("Enter Maths Marks: "))
English_Marks = int(input("Enter English Marks: "))
Science_Marks = int(input("Enter Science Marks: "))

Total_Marks_of_Three_subject = Maths_Marks + English_Marks + Science_Marks
print(f"Total marks of three subject is: {Total_Marks_of_Three_subject}")
total_marks_of_Maths_Marks_English = Maths_Marks + English_Marks
print(f"Total marks of Maths and English is: {total_marks_of_Maths_Marks_English}")

if (Maths_Marks >= 69 and
English_Marks >= 56 and
Science_Marks >= 78 and
Total_Marks_of_Three_subject >= 200) or (total_marks_of_Maths_Marks_English) >= 150:
  print("You are eligible for admission")
else:
  print("You are not eligible for admission")
# Out:
# Enter Maths Marks: 75
# Enter English Marks: 78
# Enter Science Marks: 56
# Total marks of three subject is: 209
# Total marks of Maths and English is: 153
# You are eligible for admission

# %%
Maths_Marks = int(input("Enter Maths Marks: "))
English_Marks = int(input("Enter English Marks: "))
Science_Marks = int(input("Enter Science Marks: "))

Total_Marks_of_Three_subject = Maths_Marks + English_Marks + Science_Marks
print(f"Total marks of three subject is: {Total_Marks_of_Three_subject}")
total_marks_of_Maths_Marks_English = Maths_Marks + English_Marks
print(f"Total marks of Maths and English is: {total_marks_of_Maths_Marks_English}")

if (Maths_Marks >= 69 and
English_Marks >= 56 and
Science_Marks >= 78 and
Total_Marks_of_Three_subject >= 200) or (total_marks_of_Maths_Marks_English >= 150):
  print("You are eligible for admission")
else:
  print("You are not eligible for admission")
# Out:
# Enter Maths Marks: 78
# Enter English Marks: 78
# Enter Science Marks: 76
# Total marks of three subject is: 232
# Total marks of Maths and English is: 156
# You are eligible for admission

# %%
Maths_Marks = int(input("Enter Maths Marks: "))
English_Marks = int(input("Enter English Marks: "))
Science_Marks = int(input("Enter Science Marks: "))

Total_Marks_of_Three_subject = Maths_Marks + English_Marks + Science_Marks
print(f"Total marks of three subject is: {Total_Marks_of_Three_subject}")
total_marks_of_Maths_Marks_English = Maths_Marks + English_Marks
print(f"Total marks of Maths and English is: {total_marks_of_Maths_Marks_English}")

if (Maths_Marks >= 69 and
English_Marks >= 56 and
Science_Marks >= 78 and
Total_Marks_of_Three_subject >= 200) or (total_marks_of_Maths_Marks_English) >= 150:
  print("You are eligible for admission")
else:
  print("You are not eligible for admission")
# Out:
# Enter Maths Marks: 76
# Enter English Marks: 76
# Enter Science Marks: 34
# Total marks of three subject is: 186
# Total marks of Maths and English is: 152
# You are eligible for admission

# %%
Maths_Marks = int(input("Enter Maths Marks: "))
English_Marks = int(input("Enter English Marks: "))
Science_Marks = int(input("Enter Science Marks: "))

Total_Marks_of_Three_subject = Maths_Marks + English_Marks + Science_Marks
print(f"Total marks of three subject is: {Total_Marks_of_Three_subject}")
total_marks_of_Maths_Marks_English = Maths_Marks + English_Marks
print(f"Total marks of Maths and English is: {total_marks_of_Maths_Marks_English}")

if (Maths_Marks >= 69 and
English_Marks >= 56 and
Science_Marks >= 78 and
Total_Marks_of_Three_subject >= 200) or (total_marks_of_Maths_Marks_English) >= 150:
  print("You are eligible for admission")
else:
  print("You are not eligible for admission")
# Out:
# Enter Maths Marks: 78
# Enter English Marks: 45
# Enter Science Marks: 98
# Total marks of three subject is: 221
# Total marks of Maths and English is: 123
# You are not eligible for admission

# %%
Maths_Marks = int(input("Enter Maths Marks: "))
English_Marks = int(input("Enter English Marks: "))
Science_Marks = int(input("Enter Science Marks: "))

Total_Marks_of_Three_subject = Maths_Marks + English_Marks + Science_Marks
print(f"Total marks of three subject is: {Total_Marks_of_Three_subject}")
total_marks_of_Maths_Marks_English = Maths_Marks + English_Marks
print(f"Total marks of Maths and English is: {total_marks_of_Maths_Marks_English}")

if (Maths_Marks >= 69 and
English_Marks >= 56 and
Science_Marks >= 78 and
Total_Marks_of_Three_subject >= 200) or (total_marks_of_Maths_Marks_English) >= 150:
  print("You are eligible for admission")
else:
  print("You are not eligible for admission")
# Out:
# Enter Maths Marks: 76
# Enter English Marks: 76
# Enter Science Marks: 23
# Total marks of three subject is: 175
# Total marks of Maths and English is: 152
# You are eligible for admission

# %%
Maths_Marks = int(input("Enter Maths Marks: "))
English_Marks = int(input("Enter English Marks: "))
Science_Marks = int(input("Enter Science Marks: "))

Total_Marks_of_Three_subject = Maths_Marks + English_Marks + Science_Marks
print(f"Total marks of three subject is: {Total_Marks_of_Three_subject}")
total_marks_of_Maths_Marks_English = Maths_Marks + English_Marks
print(f"Total marks of Maths and English is: {total_marks_of_Maths_Marks_English}")

if ((Maths_Marks >= 69 and
English_Marks >= 56 and
Science_Marks >= 78 and
Total_Marks_of_Three_subject >= 200) or (total_marks_of_Maths_Marks_English) >= 150):
  print("You are eligible for admission")
else:
  print("You are not eligible for admission")
# Out:
# Enter Maths Marks: 89
# Enter English Marks: 87
# Enter Science Marks: 56
# Total marks of three subject is: 232
# Total marks of Maths and English is: 176
# You are eligible for admission

# %%
Maths_Marks = int(input("Enter Maths Marks: "))
English_Marks = int(input("Enter English Marks: "))
Science_Marks = int(input("Enter Science Marks: "))

Total_Marks_of_Three_subject = Maths_Marks + English_Marks + Science_Marks
print(f"Total marks of three subject is: {Total_Marks_of_Three_subject}")
total_marks_of_Maths_Marks_English = Maths_Marks + English_Marks
print(f"Total marks of Maths and English is: {total_marks_of_Maths_Marks_English}")

if ((Maths_Marks >= 69 and
English_Marks >= 56 and
Science_Marks >= 78 and
Total_Marks_of_Three_subject >= 200) or (total_marks_of_Maths_Marks_English) >= 150):
  print("You are eligible for admission")
else:
  print("You are not eligible for admission")
# Out:
# Enter Maths Marks: 78
# Enter English Marks: 78
# Enter Science Marks: 23
# Total marks of three subject is: 179
# Total marks of Maths and English is: 156
# You are eligible for admission

# %%
Maths_Marks = int(input("Enter Maths Marks: "))
English_Marks = int(input("Enter English Marks: "))
Science_Marks = int(input("Enter Science Marks: "))

Total_Marks_of_Three_subject = Maths_Marks + English_Marks + Science_Marks
print(f"Total marks of three subject is: {Total_Marks_of_Three_subject}")
total_marks_of_Maths_Marks_English = Maths_Marks + English_Marks
print(f"Total marks of Maths and English is: {total_marks_of_Maths_Marks_English}")

if ((Maths_Marks >= 69 and
English_Marks >= 56 and
Science_Marks >= 78 and
Total_Marks_of_Three_subject >= 200) or (total_marks_of_Maths_Marks_English) >= 150):
  print("You are eligible for admission")
else:
  print("You are not eligible for admission")
# Out:
# Enter Maths Marks: 89
# Enter English Marks: 67
# Enter Science Marks: 78
# Total marks of three subject is: 234
# Total marks of Maths and English is: 156
# You are eligible for admission

# %%
Maths_Marks = int(input("Enter Maths Marks: "))
English_Marks = int(input("Enter English Marks: "))
Science_Marks = int(input("Enter Science Marks: "))

Total_Marks_of_Three_subject = Maths_Marks + English_Marks + Science_Marks
print(f"Total marks of three subject is: {Total_Marks_of_Three_subject}")
total_marks_of_Maths_Marks_English = Maths_Marks + English_Marks
print(f"Total marks of Maths and English is: {total_marks_of_Maths_Marks_English}")

if ((Maths_Marks >= 69 and
English_Marks >= 56 and
Science_Marks >= 78 and
Total_Marks_of_Three_subject >= 200) or (total_marks_of_Maths_Marks_English) >= 150):
  print("You are eligible for admission")
else:
  print("You are not eligible for admission")
# Out:
# Enter Maths Marks: 76
# Enter English Marks: 56
# Enter Science Marks: 98
# Total marks of three subject is: 230
# Total marks of Maths and English is: 132
# You are eligible for admission

# %%
Maths_Marks = int(input("Enter Maths Marks: "))
English_Marks = int(input("Enter English Marks: "))
Science_Marks = int(input("Enter Science Marks: "))

Total_Marks_of_Three_subject = Maths_Marks + English_Marks + Science_Marks
print(f"Total marks of three subject is: {Total_Marks_of_Three_subject}")
total_marks_of_Maths_Marks_English = Maths_Marks + English_Marks
print(f"Total marks of Maths and English is: {total_marks_of_Maths_Marks_English}")

if ((Maths_Marks >= 69 and
English_Marks >= 56 and
Science_Marks >= 78 and
Total_Marks_of_Three_subject >= 200) and (total_marks_of_Maths_Marks_English) >= 150):
  print("You are eligible for admission")
else:
  print("You are not eligible for admission")
# Out:
# Enter Maths Marks: 78
# Enter English Marks: 45
# Enter Science Marks: 56
# Total marks of three subject is: 179
# Total marks of Maths and English is: 123
# You are not eligible for admission

# %%
Maths_Marks = int(input("Enter Maths Marks: "))
English_Marks = int(input("Enter English Marks: "))
Science_Marks = int(input("Enter Science Marks: "))

Total_Marks_of_Three_subject = Maths_Marks + English_Marks + Science_Marks
print(f"Total marks of three subject is: {Total_Marks_of_Three_subject}")
total_marks_of_Maths_Marks_English = Maths_Marks + English_Marks
print(f"Total marks of Maths and English is: {total_marks_of_Maths_Marks_English}")

if ((Maths_Marks >= 69 and
English_Marks >= 56 and
Science_Marks >= 78 and
Total_Marks_of_Three_subject >= 200) and (total_marks_of_Maths_Marks_English) >= 150):
  print("You are eligible for admission")
else:
  print("You are not eligible for admission")
# Out:
# Enter Maths Marks: 78
# Enter English Marks: 78
# Enter Science Marks: 34
# Total marks of three subject is: 190
# Total marks of Maths and English is: 156
# You are not eligible for admission

# %%
Maths_Marks = int(input("Enter Maths Marks: "))
English_Marks = int(input("Enter English Marks: "))
Science_Marks = int(input("Enter Science Marks: "))

Total_Marks_of_Three_subject = Maths_Marks + English_Marks + Science_Marks
print(f"Total marks of three subject is: {Total_Marks_of_Three_subject}")
total_marks_of_Maths_Marks_English = Maths_Marks + English_Marks
print(f"Total marks of Maths and English is: {total_marks_of_Maths_Marks_English}")

if ((Maths_Marks >= 69 and
English_Marks >= 56 and
Science_Marks >= 78 and
Total_Marks_of_Three_subject >= 200) and (total_marks_of_Maths_Marks_English) >= 150):
  print("You are eligible for admission")
else:
  print("You are not eligible for admission")
# Out:
# Enter Maths Marks: 89
# Enter English Marks: 56
# Enter Science Marks: 89
# Total marks of three subject is: 234
# Total marks of Maths and English is: 145
# You are not eligible for admission

# %%
n = int(input("Enter number of students: "))

for i in range(n):
    print(f"\nStudent {i+1}")

    name = input("Enter student name: ")

    Maths_Marks = int(input("Enter Maths Marks: "))
    English_Marks = int(input("Enter English Marks: "))
    Science_Marks = int(input("Enter Science Marks: "))

    Total_Marks_of_Three_subject = Maths_Marks + English_Marks + Science_Marks
    total_marks_of_Maths_English = Maths_Marks + English_Marks

    print(f"Total marks of three subjects: {Total_Marks_of_Three_subject}")
    print(f"Total marks of Maths and English: {total_marks_of_Maths_English}")

    if (
        Maths_Marks >= 69 and
        English_Marks >= 56 and
        Science_Marks <= 90 and
        Total_Marks_of_Three_subject >= 200 and
        total_marks_of_Maths_English >= 150
    ):
        print(f"{name} is eligible for admission ✅")
    else:
        print(f"{name} is not eligible for admission ❌")
# Out:
# Enter number of students: 2
#
# Student 1
# Enter student name: Raju
# Enter Maths Marks: 78
# Enter English Marks: 78
# Enter Science Marks: 76
# Total marks of three subjects: 232
# Total marks of Maths and English: 156
# Raju is eligible for admission ✅
#
# Student 2
# Enter student name: Rakesh
# Enter Maths Marks: 56
# Enter English Marks: 78
# Enter Science Marks: 95
# Total marks of three subjects: 229
# Total marks of Maths and English: 134
# Rakesh is not eligible for admission ❌

# %%
n = int(input("Enter number of students: "))

for i in range(n):
    print(f"\nStudent {i+1}")

    name = input("Enter student name: ")

    Maths_Marks = int(input("Enter Maths Marks: "))
    English_Marks = int(input("Enter English Marks: "))
    Science_Marks = int(input("Enter Science Marks: "))

    Total_Marks_of_Three_subject = Maths_Marks + English_Marks + Science_Marks
    total_marks_of_Maths_English = Maths_Marks + English_Marks

    print(f"Total marks of three subjects: {Total_Marks_of_Three_subject}")
    print(f"Total marks of Maths and English: {total_marks_of_Maths_English}")

    if (
        Maths_Marks >= 69 and
        English_Marks >= 56 and
        Science_Marks <= 90 and
        Total_Marks_of_Three_subject >= 200 or
        total_marks_of_Maths_English >= 150
    ):
        print(f"{name} is eligible for admission ✅")
    else:
        print(f"{name} is not eligible for admission ❌")
# Out:
# Enter number of students: 2
#
# Student 1
# Enter student name: rahul
# Enter Maths Marks: 56
# Enter English Marks: 78
# Enter Science Marks: 96
# Total marks of three subjects: 230
# Total marks of Maths and English: 134
# rahul is not eligible for admission ❌
#
# Student 2
# Enter student name: Raj
# Enter Maths Marks: 78
# Enter English Marks: 79
# Enter Science Marks: 34
# Total marks of three subjects: 191
# Total marks of Maths and English: 157
# Raj is eligible for admission ✅

# %%
n = int(input("Enter number of students: "))

for i in range(n):
    print(f"\nStudent {i+1}")

    name = input("Enter student name: ")

    Maths_Marks = int(input("Enter Maths Marks: "))
    English_Marks = int(input("Enter English Marks: "))
    Science_Marks = int(input("Enter Science Marks: "))

    Total_Marks_of_Three_subject = Maths_Marks + English_Marks + Science_Marks
    total_marks_of_Maths_English = Maths_Marks + English_Marks

    print(f"Total marks of three subjects: {Total_Marks_of_Three_subject}")
    print(f"Total marks of Maths and English: {total_marks_of_Maths_English}")

    if (
        Maths_Marks >= 69 and
        English_Marks >= 56 and
        Science_Marks <= 90 and
        Total_Marks_of_Three_subject >= 200 and
        total_marks_of_Maths_English >= 150
    ):
        print(f"{name} is eligible for admission ✅")
    else:
        print(f"{name} is not eligible for admission ❌")
# Out:
# Enter number of students: 2
#
# Student 1
# Enter student name: Rakesh
# Enter Maths Marks: 78
# Enter English Marks: 78
# Enter Science Marks: 32
# Total marks of three subjects: 188
# Total marks of Maths and English: 156
# Rakesh is not eligible for admission ❌
#
# Student 2
# Enter student name: Rakesh
# Enter Maths Marks: 78
# Enter English Marks: 78
# Enter Science Marks: 79
# Total marks of three subjects: 235
# Total marks of Maths and English: 156
# Rakesh is eligible for admission ✅

# %%
n = int(input("Enter number of students: "))

for i in range(n):
    print(f"\nStudent {i+1}")

    name = input("Enter student name: ")

    Maths_Marks = int(input("Enter Maths Marks: "))
    English_Marks = int(input("Enter English Marks: "))
    Science_Marks = int(input("Enter Science Marks: "))

    Total_Marks_of_Three_subject = Maths_Marks + English_Marks + Science_Marks
    total_marks_of_Maths_English = Maths_Marks + English_Marks

    print(f"Total marks of three subjects: {Total_Marks_of_Three_subject}")
    print(f"Total marks of Maths and English: {total_marks_of_Maths_English}")

    if (
        Maths_Marks >= 69 and
        English_Marks >= 56 or
        Science_Marks <= 90 and
        Total_Marks_of_Three_subject >= 200 and
        total_marks_of_Maths_English >= 150
    ):
        print(f"{name} is eligible for admission ✅")
    else:
        print(f"{name} is not eligible for admission ❌")
# Out:
# Enter number of students: 2
#
# Student 1
# Enter student name: Rahul
# Enter Maths Marks: 75
# Enter English Marks: 45
# Enter Science Marks: 89
# Total marks of three subjects: 209
# Total marks of Maths and English: 120
# Rahul is not eligible for admission ❌
#
# Student 2
# Enter student name: ramesh
# Enter Maths Marks: 78
# Enter English Marks: 67
# Enter Science Marks: 56
# Total marks of three subjects: 201
# Total marks of Maths and English: 145
# ramesh is eligible for admission ✅
